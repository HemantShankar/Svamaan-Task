# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df1= pd.read_csv('sep.csv')
df2= pd.read_csv('feb.csv')
# Out:
# C:\Users\Hemant Shankar\AppData\Local\Temp\ipykernel_19668\4027629488.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1= pd.read_csv('sep.csv')

# %%
df1.head()
# Out:
#   State Name Branch Name  Village Name Center Name Customer Name  \
# 0         S2         AUR           244          99          C100
# 1         S1         HOS           515          36          C101
# 2         S2         BAS           196          11          C102
# 3         S2         PAL           273          14          C103
# 4         S2         PAL           272          16          C104
#
#    Out Standing Principal  Num Days Since Last Due       Bucket Name
# 0                  672.04                        0  Current (0 Days)
# 1                  454.11                        0  Current (0 Days)
# 2                  371.22                        0  Current (0 Days)
# 3                 9752.71                        0  Current (0 Days)
# 4                11024.70                        0  Current (0 Days)

# %%
df2.head()
# Out:
#   State BRANCH NAME  VillageName Center Customer_Name  OutStanding_Principal  \
# 0    S2         PAL          271     37          C100                   5820
# 1    S2         AUR          239     17          C101                   2117
# 2    S2         PAL          272     33          C102                  11478
# 3    S2         AMB          229     39          C103                   3730
# 4    S2         NAN          197     39          C104                   5734
#
#    Num_Days_SinceLAstDue       Bucket_Name
# 0                      0  Current (0 Days)
# 1                      0  Current (0 Days)
# 2                      0  Current (0 Days)
# 3                      0  Current (0 Days)
# 4                      0  Current (0 Days)

# %%
df2 = df2.rename(columns={'State': 'State Name','BRANCH NAME': 'Branch Name', 'VillageName': 'Village Name', 'Center': 'Center Name', 'Customer_Name': 'Customer Name', 'OutStanding_Principal': 'OutStanding Principal', 'Num_Days_SinceLAstDue': 'Num Days Since Last Due', 'Bucket_Name': 'Bucket Name'} )

# %%
df2.head()
# Out:
#   State Name Branch Name  Village Name Center Name Customer Name  \
# 0         S2         PAL           271          37          C100
# 1         S2         AUR           239          17          C101
# 2         S2         PAL           272          33          C102
# 3         S2         AMB           229          39          C103
# 4         S2         NAN           197          39          C104
#
#    OutStanding Principal  Num Days Since Last Due       Bucket Name
# 0                   5820                        0  Current (0 Days)
# 1                   2117                        0  Current (0 Days)
# 2                  11478                        0  Current (0 Days)
# 3                   3730                        0  Current (0 Days)
# 4                   5734                        0  Current (0 Days)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65648 entries, 0 to 65647
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   State Name               65648 non-null  object
#  1   Branch Name              65648 non-null  object
#  2   Village Name             65648 non-null  int64
#  3   Center Name              65648 non-null  object
#  4   Customer Name            65648 non-null  object
#  5   Out Standing Principal   65648 non-null  float64
#  6   Num Days Since Last Due  65648 non-null  int64
#  7   Bucket Name              65648 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 4.0+ MB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85676 entries, 0 to 85675
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   State Name               85676 non-null  object
#  1   Branch Name              85676 non-null  object
#  2   Village Name             85676 non-null  int64
#  3   Center Name              85676 non-null  object
#  4   Customer Name            85676 non-null  object
#  5   OutStanding Principal    85676 non-null  int64
#  6   Num Days Since Last Due  85676 non-null  int64
#  7   Bucket Name              85676 non-null  object
# dtypes: int64(3), object(5)
# memory usage: 5.2+ MB

# %%
df1['Bucket Name'].unique()
# Out:
# array(['Current (0 Days)', 'W1(1-7 Days)', 'W2(8-14 Days)',
#        'W3(15-21 Days)', 'W4(22-30 Days)', '31-60 Days', '61-90 Days',
#        '91-120 Days', '121-150 Days', '151-180 Days', '181-275 Days',
#        '276-365 Days', '>365 Days'], dtype=object)

# %%
df1['Num Days Since Last Due'].unique()
# Out:
# array([  0,   6,   2,   7,   3,   1,  13,  14,   8,  10,   9,  21,  15,
#         16,  20,  17,  29,  22,  24,  28,  30,  23,  27,  50,  43,  37,
#         41,  36,  38,  34,  35,  31,  51,  42,  59,  44,  48,  49,  52,
#         45,  58,  56,  57,  55,  86,  77,  72,  69,  84,  76,  79,  90,
#         65,  71,  78,  63,  85,  62,  64,  80,  70,  83,  87,  73,  66,
#        106, 118,  91, 104,  97,  99,  93,  92, 120, 114, 101, 107, 111,
#         94, 105, 108,  98, 113, 112, 119, 100, 115, 125, 133, 142, 149,
#        126, 132, 139, 127, 147, 148, 146, 140, 128, 141, 134, 135, 136,
#        121, 150, 129, 176, 177, 154, 163, 170, 161, 162, 156, 168, 153,
#        169, 167, 155, 175, 174, 160, 182, 252, 204, 223, 181, 218, 191,
#        183, 184, 239, 253, 240, 211, 209, 268, 189, 217, 261, 260, 227,
#        205, 245, 238, 210, 267, 188, 232, 246, 198, 226, 202, 233, 196,
#        195, 241, 220, 274, 212, 247, 266, 216, 344, 363, 316, 282, 350,
#        365, 323, 330, 279, 302, 337, 541, 391, 386, 392, 371], dtype=int64)

# %%
df1['Customer Name'].unique()
# Out:
# array(['C100', 'C101', 'C102', ..., 'C65745', 'C65746', 'C65747'],
#       dtype=object)

# %%
df1['Branch Name'].unique()
# Out:
# array(['AUR', 'HOS', 'BAS', 'PAL', 'KIN', 'HAD', 'AMB', 'BAL', 'NIL',
#        'SHA', 'AKA', 'NAN', 'PAI', 'SIN', 'SAN', 'KUD', 'SIL', 'AHM',
#        'SHI', 'NAI', 'GAN', 'LAT', 'PAC', 'DHU', 'BAD', 'CHA', 'SOR',
#        'MEH', 'DEU', 'KRI', 'DAL', 'GAR', 'GUN', 'TUR', 'SIR', 'ROB',
#        'HOL', 'MOT', 'RAM', 'NAR', 'JIN', 'SHE', 'BAG', 'REN', 'JAP',
#        'KUN', 'RUN', 'PAT', 'BAH', 'PHU', 'BHA', 'LAH', 'CHH', 'SAK'],
#       dtype=object)

# %%
result_df = pd.merge(df1, df2, on=['Customer Name', 'State Name'], how='inner')
result_df.head()
# Out:
#   State Name Branch Name_x  Village Name_x Center Name_x Customer Name  \
# 0         S2           AUR             244            99          C100
# 1         S2           BAS             196            11          C102
# 2         S2           PAL             273            14          C103
# 3         S2           PAL             272            16          C104
# 4         S2           AUR             242            14          C105
#
#    Out Standing Principal  Num Days Since Last Due_x     Bucket Name_x  \
# 0                  672.04                          0  Current (0 Days)
# 1                  371.22                          0  Current (0 Days)
# 2                 9752.71                          0  Current (0 Days)
# 3                11024.70                          0  Current (0 Days)
# 4                  482.41                          0  Current (0 Days)
#
#   Branch Name_y  Village Name_y Center Name_y  OutStanding Principal  \
# 0           PAL             271            37                   5820
# 1           PAL             272            33                  11478
# 2           AMB             229            39                   3730
# 3           NAN             197            39                   5734
# 4           NAN             197            39                   2425
#
#    Num Days Since Last Due_y     Bucket Name_y
# 0                          0  Current (0 Days)
# 1                          0  Current (0 Days)
# 2                          0  Current (0 Days)
# 3                          0  Current (0 Days)
# 4                          0  Current (0 Days)

# %%
result_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21393 entries, 0 to 21392
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   State Name                 21393 non-null  object
#  1   Branch Name_x              21393 non-null  object
#  2   Village Name_x             21393 non-null  int64
#  3   Center Name_x              21393 non-null  object
#  4   Customer Name              21393 non-null  object
#  5   Out Standing Principal     21393 non-null  float64
#  6   Num Days Since Last Due_x  21393 non-null  int64
#  7   Bucket Name_x              21393 non-null  object
#  8   Branch Name_y              21393 non-null  object
#  9   Village Name_y             21393 non-null  int64
#  10  Center Name_y              21393 non-null  object
#  11  OutStanding Principal      21393 non-null  int64
#  12  Num Days Since Last Due_y  21393 non-null  int64
#  13  Bucket Name_y              21393 non-null  object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 2.4+ MB

# %%
pdf= result_df[result_df['Bucket Name_x']== '151-180 Days']
pdf
# Out:
#       State Name Branch Name_x  Village Name_x Center Name_x Customer Name  \
# 21285         S2           AKA             212            16        C65447
# 21286         S2           SIL             235            41        C65448
# 21287         S2           CHA             274            35        C65449
# 21288         S2           BAD             225            35        C65451
# 21289         S2           LAT             351            43        C65454
# ...          ...           ...             ...           ...           ...
# 21352         S2           PAC             286            12        C65578
# 21353         S2           SIL             237            17        C65579
# 21354         S2           AMB             226            17        C65580
# 21355         S2           BAD             227            19        C65581
# 21356         S2           AMB             228            17        C65583
#
#        Out Standing Principal  Num Days Since Last Due_x Bucket Name_x  \
# 21285                 9469.76                        177  151-180 Days
# 21286                21421.32                        154  151-180 Days
# 21287                  967.56                        163  151-180 Days
# 21288                12287.59                        176  151-180 Days
# 21289                18534.77                        154  151-180 Days
# ...                       ...                        ...           ...
# 21352                10258.72                        170  151-180 Days
# 21353                 8092.60                        155  151-180 Days
# 21354                 5155.09                        177  151-180 Days
# 21355                 7809.06                        175  151-180 Days
# 21356                 2923.40                        170  151-180 Days
#
#       Branch Name_y  Village Name_y Center Name_y  OutStanding Principal  \
# 21285           KIN             192            14                  40000
# 21286           GAN             220            56                  28326
# 21287           AUR             242            13                  38742
# 21288           KIN             192            13                  38734
# 21289           KIN             192            13                  39054
# ...             ...             ...           ...                    ...
# 21352           NAI             200            17                  38423
# 21353           NAI             200            17                  48421
# 21354           NAI             200            42                  48421
# 21355           NIL             358            13                  38423
# 21356           NIL             358            13                  38423
#
#        Num Days Since Last Due_y     Bucket Name_y
# 21285                          0  Current (0 Days)
# 21286                          0  Current (0 Days)
# 21287                          0  Current (0 Days)
# 21288                          0  Current (0 Days)
# 21289                          0  Current (0 Days)
# ...                          ...               ...
# 21352                          0  Current (0 Days)
# 21353                          0  Current (0 Days)
# 21354                          0  Current (0 Days)
# 21355                          0  Current (0 Days)
# 21356                          0  Current (0 Days)
#
# [72 rows x 14 columns]

# %%
result_df['Due Diff(in days)']= result_df['Num Days Since Last Due_y'] - result_df['Num Days Since Last Due_x']
result_df.tail()
# Out:
#       State Name Branch Name_x  Village Name_x Center Name_x Customer Name  \
# 21388         S2           NAN             197            70        C65696
# 21389         S2           PAI             244            42        C65697
# 21390         S2           AMB             347            12        C65730
# 21391         S2           AMB             227            47        C65734
# 21392         S2           SHI             117            19        C65747
#
#        Out Standing Principal  Num Days Since Last Due_x     Bucket Name_x  \
# 21388                14657.13                        182      181-275 Days
# 21389                20746.16                        232      181-275 Days
# 21390                20400.70                        350      276-365 Days
# 21391                30247.66                        330      276-365 Days
# 21392                 1069.89                          0  Current (0 Days)
#
#       Branch Name_y  Village Name_y Center Name_y  OutStanding Principal  \
# 21388           LAT             352            77                  19081
# 21389           AUR             237            20                  19084
# 21390           PAI             245            43                  48421
# 21391           SHA             279            12                  38741
# 21392           AMB             349            88                  23843
#
#        Num Days Since Last Due_y     Bucket Name_y  Due Diff(in days)
# 21388                          0  Current (0 Days)               -182
# 21389                          0  Current (0 Days)               -232
# 21390                          0  Current (0 Days)               -350
# 21391                          0  Current (0 Days)               -330
# 21392                          0  Current (0 Days)                  0

# %%
result_df['value_x'] = result_df['Bucket Name_x'].str.extract('(\d+)')
result_df['value_y'] = result_df['Bucket Name_y'].str.extract('(\d+)')

# Convert the extracted values to numeric
result_df['value_x'] = pd.to_numeric(result_df['value_x'], errors='coerce')
result_df['value_y'] = pd.to_numeric(result_df['value_y'], errors='coerce')

# Create a new column 'bucket_difference' to store the difference
result_df['bucket_difference'] = result_df['value_x'] - result_df['value_y']
result_df['principal_difference'] = result_df['OutStanding Principal'] - result_df['Out Standing Principal']
# Create a new column 'difference_direction' to indicate positive or negative difference
result_df['Bucket Movement'] = result_df['bucket_difference'].apply(lambda x: 'Improvement' if x > 0 else 'Deterioration' if x < 0 else 'Same')
result_df['Out Principal'] = result_df['principal_difference'].apply(lambda x: 'Increase' if x > 0 else 'Decrease' if x < 0 else 'Same')
# Deciding Portfolio Quality
conditions = [
    ((result_df['Bucket Movement'] == 'Improvement') & (result_df['Out Principal'] == 'Decrease')),
    ((result_df['Bucket Movement'] == 'Deterioration') & (result_df['Out Principal'] == 'Increase')),
    ((result_df['Bucket Movement'] == 'Same') & (result_df['Out Principal'] == 'Same')),
    ((result_df['Bucket Movement'] == 'Same') & (result_df['Out Principal'] == 'Increase')),
    ((result_df['Bucket Movement'] == 'Same') & (result_df['Out Principal'] == 'Decrease')),
    ((result_df['Bucket Movement'] == 'Improvement') & (result_df['Out Principal'] == 'Same')),
    ((result_df['Bucket Movement'] == 'Deterioration') & (result_df['Out Principal'] == 'Same')),
    ((result_df['Bucket Movement'] == 'Improvement') & (result_df['Out Principal'] == 'Increase')),
    ((result_df['Bucket Movement'] == 'Deterioration') & (result_df['Out Principal'] == 'Decrease'))
]

choices = ['Excellent', 'Worse', 'Good','Need Improvement', 'Good', 'Better', 'Need Improvement', 'Good', 'Need Improvement']
result_df['Portfolio Quality'] = np.select(conditions, choices, default='Unknown')

result_df = result_df.drop(['value_x', 'value_y', 'bucket_difference', 'principal_difference'], axis=1)
result_df.head(10)
# Out:
#   State Name Branch Name_x  Village Name_x Center Name_x Customer Name  \
# 0         S2           AUR             244            99          C100
# 1         S2           BAS             196            11          C102
# 2         S2           PAL             273            14          C103
# 3         S2           PAL             272            16          C104
# 4         S2           AUR             242            14          C105
# 5         S2           KIN             192            44          C106
# 6         S2           AMB             228            46          C109
# 7         S2           AUR             239            16          C110
# 8         S2           KIN             192            44          C111
# 9         S2           NIL             357            15          C114
#
#    Out Standing Principal  Num Days Since Last Due_x     Bucket Name_x  \
# 0                  672.04                          0  Current (0 Days)
# 1                  371.22                          0  Current (0 Days)
# 2                 9752.71                          0  Current (0 Days)
# 3                11024.70                          0  Current (0 Days)
# 4                  482.41                          0  Current (0 Days)
# 5                 1845.74                          0  Current (0 Days)
# 6                 2507.35                          0  Current (0 Days)
# 7                  421.47                          0  Current (0 Days)
# 8                  980.35                          0  Current (0 Days)
# 9                 1661.04                          0  Current (0 Days)
#
#   Branch Name_y  Village Name_y Center Name_y  OutStanding Principal  \
# 0           PAL             271            37                   5820
# 1           PAL             272            33                  11478
# 2           AMB             229            39                   3730
# 3           NAN             197            39                   5734
# 4           NAN             197            39                   2425
# 5           BAD             225            39                   1069
# 6           HAD             179            91                    579
# 7           BAS             196            56                     13
# 8           AMB             226            45                   2425
# 9           AMB             228            50                   1474
#
#    Num Days Since Last Due_y     Bucket Name_y  Due Diff(in days)  \
# 0                          0  Current (0 Days)                  0
# 1                          0  Current (0 Days)                  0
# 2                          0  Current (0 Days)                  0
# 3                          0  Current (0 Days)                  0
# 4                          0  Current (0 Days)                  0
# 5                          0  Current (0 Days)                  0
# 6                          0  Current (0 Days)                  0
# 7                          0  Current (0 Days)                  0
# 8                          0  Current (0 Days)                  0
# 9                          0  Current (0 Days)                  0
#
#   Bucket Movement Out Principal Portfolio Quality
# 0            Same      Increase  Need Improvement
# 1            Same      Increase  Need Improvement
# 2            Same      Decrease              Good
# 3            Same      Decrease              Good
# 4            Same      Increase  Need Improvement
# 5            Same      Decrease              Good
# 6            Same      Decrease              Good
# 7            Same      Decrease              Good
# 8            Same      Increase  Need Improvement
# 9            Same      Decrease              Good

# %%
value_counts = result_df['State Name'].value_counts()
value_counts
# Out:
# S2    14208
# S1     5119
# S3     1763
# S5      161
# S6      125
# S4       17
# Name: State Name, dtype: int64

# %%
value_counts = result_df['Portfolio Quality'].value_counts()
value_counts
# Out:
# Good                13330
# Need Improvement     8020
# Excellent              43
# Name: Portfolio Quality, dtype: int64

# %%
# Count the occurrences of each 'Portfolio Quality' value for each 'State'
portfolio_counts = result_df.groupby(['State Name', 'Portfolio Quality']).size().unstack(fill_value=0)
portfolio_counts
# Out:
# Portfolio Quality  Excellent  Good  Need Improvement
# State Name
# S1                        37  4213               869
# S2                         6  7641              6561
# S3                         0  1263               500
# S4                         0    14                 3
# S5                         0    97                64
# S6                         0   102                23
